# %%
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
import logging

for handler in logging.root.handlers:
    logging.root.removeHandler(handler)
logging.basicConfig(level=logging.INFO)

# %%
# Set project root
from pathlib import Path

PROJECT_ROOT = Path("..").resolve()
PROJECT_ROOT_LS = [p.name for p in PROJECT_ROOT.iterdir()]
assert "featurologists" in PROJECT_ROOT_LS, f"Not a project root? {PROJECT_ROOT}, pwd: {Path().resolve()}"

# %%
import pandas as pd
from customer_segmentation_toolkit.data_zoo import download_data_csv

from featurologists.data_transforms import build_client_clusters, clean_client_clusters
from featurologists.models.customer_segmentation import (
    calc_score_roc_auc,
    calc_score_accuracy,
    train_test_split,
    save_model,
    train_lightgbm,
    train_xgboost,
)

# %%
df = pd.read_csv(PROJECT_ROOT/'data/output/offline_clusters.csv')
df
# Out:
#       CustomerID  count       min       max          mean       sum  \
# 0        12346.0      1  77183.60  77183.60  77183.600000  77183.60
# 1        12347.0      5    382.52    711.79    558.172000   2790.86
# 2        12348.0      4    227.44    892.80    449.310000   1797.24
# 3        12350.0      1    334.40    334.40    334.400000    334.40
# 4        12352.0      7    120.33    840.30    313.472857   2194.31
# ...          ...    ...       ...       ...           ...       ...
# 3611     18280.0      1    180.60    180.60    180.600000    180.60
# 3612     18281.0      1     80.82     80.82     80.820000     80.82
# 3613     18282.0      1    100.21    100.21    100.210000    100.21
# 3614     18283.0     10      2.50    192.80    108.683000   1086.83
# 3615     18287.0      1    765.28    765.28    765.280000    765.28
#
#         categ_0    categ_1    categ_2    categ_3     categ_4  LastPurchase  \
# 0      0.000000   0.000000   0.000000   0.000000  100.000000           255
# 1     43.755688  12.621916  10.442659   3.790946   29.388791            59
# 2     20.030714   0.000000  35.692506   2.323563   41.953217             5
# 3     11.961722  27.900718   5.592105   6.100478   48.444976           240
# 4     78.004019   4.798775   0.464839   2.983170   13.749197             2
# ...         ...        ...        ...        ...         ...           ...
# 3611  47.840532  41.140642   0.000000  11.018826    0.000000           207
# 3612  41.945063  18.930958  18.708241   0.000000   20.415739           110
# 3613  25.446562  40.564814  20.516914  13.471709    0.000000            56
# 3614   9.789940  29.352337  15.616978  10.617116   34.623630            25
# 3615   6.402885  17.601401   5.315701   0.000000   70.680013           131
#
#       FirstPurchase  cluster
# 0               255        2
# 1               297        6
# 2               288        0
# 3               240       10
# 4               226        1
# ...             ...      ...
# 3611            207        3
# 3612            110        6
# 3613             56        3
# 3614            267        0
# 3615            131       10
#
# [3616 rows x 14 columns]

# %%
df = clean_client_clusters(df)
df
# Out:
# INFO:root:Cluster sizes:     cluster  cluster_size
# 0         0           577
# 1         1           663
# 2         2             1
# 3         3           324
# 4         4             7
# 5         5           181
# 6         6          1336
# 7         7            93
# 8         8             9
# 9         9           125
# 10       10           300
# WARNING:root:Detected 1 clusters with 1 element: [2]
#       CustomerID  count       min       max          mean       sum  \
# 0        12346.0      1  77183.60  77183.60  77183.600000  77183.60
# 1        12347.0      5    382.52    711.79    558.172000   2790.86
# 2        12348.0      4    227.44    892.80    449.310000   1797.24
# 3        12350.0      1    334.40    334.40    334.400000    334.40
# 4        12352.0      7    120.33    840.30    313.472857   2194.31
# ...          ...    ...       ...       ...           ...       ...
# 3612     18281.0      1     80.82     80.82     80.820000     80.82
# 3613     18282.0      1    100.21    100.21    100.210000    100.21
# 3614     18283.0     10      2.50    192.80    108.683000   1086.83
# 3615     18287.0      1    765.28    765.28    765.280000    765.28
# 3616     12346.0      1  77183.60  77183.60  77183.600000  77183.60
#
#         categ_0    categ_1    categ_2    categ_3     categ_4  LastPurchase  \
# 0      0.000000   0.000000   0.000000   0.000000  100.000000           255
# 1     43.755688  12.621916  10.442659   3.790946   29.388791            59
# 2     20.030714   0.000000  35.692506   2.323563   41.953217             5
# 3     11.961722  27.900718   5.592105   6.100478   48.444976           240
# 4     78.004019   4.798775   0.464839   2.983170   13.749197             2
# ...         ...        ...        ...        ...         ...           ...
# 3612  41.945063  18.930958  18.708241   0.000000   20.415739           110
# 3613  25.446562  40.564814  20.516914  13.471709    0.000000            56
# 3614   9.789940  29.352337  15.616978  10.617116   34.623630            25
# 3615   6.402885  17.601401   5.315701   0.000000   70.680013           131
# 3616   0.000000   0.000000   0.000000   0.000000  100.000000           255
#
#       FirstPurchase  cluster
# 0               255        2
# 1               297        6
# 2               288        0
# 3               240       10
# 4               226        1
# ...             ...      ...
# 3612            110        6
# 3613             56        3
# 3614            267        0
# 3615            131       10
# 3616            255        2
#
# [3617 rows x 14 columns]

# %%
X_train, X_test, Y_train, Y_test = train_test_split(df)
X_train.shape, X_test.shape, Y_train.shape, Y_test.shape
# Out:
# ((2893, 6), (724, 6), (2893,), (724,))

# %%
xgboost_model = train_xgboost(X_train, Y_train)
xgboost_model
# Out:
# XGBClassifier(base_score=0.5, booster='gbtree', colsample_bylevel=1,
#               colsample_bynode=1, colsample_bytree=1, eval_metric='aucpr',
#               gamma=0, gpu_id=-1, importance_type='gain',
#               interaction_constraints='', learning_rate=0.16, max_delta_step=0,
#               max_depth=50, min_child_weight=1, missing=nan,
#               monotone_constraints='()', n_estimators=100, n_jobs=12,
#               num_parallel_tree=1, objective='multi:softprob', random_state=0,
#               reg_alpha=0, reg_lambda=1, scale_pos_weight=None, subsample=1,
#               tree_method='exact', use_label_encoder=False,
#               validate_parameters=1, verbosity=None)

# %%
xgboost_score_accuracy = calc_score_accuracy(xgboost_model, X_test, Y_test)
print(f"XGBoost score_accuracy: {xgboost_score_accuracy:.6f}")
# Out:
# XGBoost score_accuracy: 0.943370

# %%
lightgbm_model = train_lightgbm(X_train, Y_train)
lightgbm_model
# Out:
# /plain/github/opensource/Featurologists/venv/lib/python3.7/site-packages/lightgbm/engine.py:148: UserWarning: Found `n_estimators` in params. Will use it instead of argument
#   _log_warning("Found `{}` in params. Will use it instead of argument".format(alias))

# %%
lightgbm_score_accuracy = calc_score_accuracy(lightgbm_model, X_test, Y_test)
print(f"LightGBM score_accuracy: {lightgbm_score_accuracy}")
# Out:
# LightGBM score_accuracy: 0.9392265193370166

# %%
MODELS_DIR = PROJECT_ROOT / "models" / "customer_segmentation"
! rm -r {MODELS_DIR}

save_model(
    xgboost_model, MODELS_DIR / "xgboost", metadata={"score_accuracy": xgboost_score_accuracy}
)
save_model(
    lightgbm_model, MODELS_DIR / "lightgbm", metadata={"score_accuracy": lightgbm_score_accuracy}
)

[p.name for p in MODELS_DIR.iterdir()]
# Out:
# ['lightgbm', 'xgboost']
